# %% [markdown]
# # Exploration notebook

# %% [markdown]
# ## Imports

# %%
from source_code.utils import load_dataset, preprocess, plot_random_example
from source_code.models import kSVD

# %% [markdown]
# ## Loading data

# %%
dataset_name = 'BME'
train_dataset, test_dataset = load_dataset(dataset_name)

train_matrix, train_labels = preprocess(train_dataset, serie_length=128)
test_matrix, test_labels = preprocess(test_dataset, serie_length=128)

# %% [markdown]
# ## Fit kSVD (dictionnary learning + sparse coding)

# %%
dict_size = 500
sparsity = 20

approx_ksvd = kSVD(n_components=dict_size).fit(train_matrix, sparsity)
alphas = approx_ksvd.encode(train_matrix, sparsity)
D = approx_ksvd.components_

# %% [markdown]
# ### Example

# %%
plot_random_example(train_matrix, alphas, D)
